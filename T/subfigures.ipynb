# %%
import numpy as np
import sympy as sym

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec
from matplotlib.gridspec import GridSpecFromSubplotSpec

# %%
sns.set_theme(context='notebook', style='ticks', palette='pastel', 
              font='sans-serif', font_scale=1, color_codes=True, rc={"axes.edgecolor":'#1560bd',
                                                                     "xtick.color":'#002fa7',"ytick.color":'#002fa7'})

# %%
fig = plt.figure(figsize = (10,5), layout = 'constrained')

sf = fig.subfigures(1,2, width_ratios=[2,1], wspace = 0.07)

gs = GridSpec(1,2, figure = sf[0])

ax1 = sf[0].add_subplot(gs[0,0])
ax2 = sf[0].add_subplot(gs[0,1])

ax3,ax4 = sf[1].subplots(2,1)

fig.suptitle('SUPER TITLE', color = 'navy', fontsize = 25)
fig.supxlabel('Super X label', color = 'navy', fontsize = 25)
fig.supylabel('Super Y label', color = 'navy', fontsize = 25)

sf[0].suptitle('Sub figure Title Left', color = 'blue', fontsize = 15)
sf[0].supxlabel('Sub figure x label', color = 'blue', fontsize = 15)
sf[0].supylabel('Sub figure y label', color = 'blue', fontsize = 15)

sf[1].suptitle('Sub figure Title Right', color = 'blue', fontsize = 15)
sf[1].supxlabel('Sub figure x label', color = 'blue', fontsize = 15)
sf[1].supylabel('Sub figure y label', color = 'blue', fontsize = 15)


for j,i in enumerate([ax1,ax2,ax3,ax4]):
    i.set_title(f'Subplot {j+1}', color = '#0073cf', fontsize = 10)
    i.set_xlabel('x', color = '#0073cf', fontsize = 10)
    i.set_ylabel('y', color = '#0073cf', fontsize = 10)


plt.show()
